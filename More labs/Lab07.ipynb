# %%
class BTNode:
  def __init__(self, elem):
    self.elem = elem
    self.right = None
    self.left = None

# %%
def inorder(root):
  if root == None:
    return

  inorder(root.left)
  print(root.elem, end = ' ')
  inorder(root.right)

# %%
def tree_construction(arr, i = 1):
  if i>=len(arr) or arr[i] == None:
    return None
  p = BTNode(arr[i])
  p.left = tree_construction(arr, 2*i)
  p.right = tree_construction(arr, 2*i+1)
  return p


root2 = tree_construction([None, 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', None, None, None, 'I', 'J', None, 'k'])
inorder(root2)
# Out:
# H D B E A I F J C G k

# %% [markdown]
# Task 1

# %%
def convert_mirror(root):
  #To Do
  if root == None:
    return None

  a = root.left
  b = root.right
  root.left , root.right = root.right , root.left
  convert_mirror(a)
  convert_mirror(b)
  return root

#DRIVER CODE
root = BTNode(10)
n1 = BTNode(20)
n2 = BTNode(30)
n3 = BTNode(40)
n4 = BTNode(60)

root.left = n1
root.right = n2

n1.left = n3
n1.right = n4

print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  40 20 60 10 30
print()

root2 = convert_mirror(root)
print('Mirrored Tree Inorder Traversal: ', end = ' ')
inorder(root2) #Mirrored Tree Inorder Traversal:  30 10 60 20 40
# Out:
# Given Tree Inorder Traversal:  40 20 60 10 30
# Mirrored Tree Inorder Traversal:  30 10 60 20 40

# %% [markdown]
# Task 2

# %%
from collections import deque

def smallest_level(root):
  #To Do
  if root == None:
    return {}

  min_l = {}
  queue = deque([(root, 0)])
  while queue:
    a = queue.popleft()
    node, level = a
    b = level+1
    d = node.elem
    e = node.left
    f = node.right
    if level not in min_l:
      min_l[level] = d
    else:
      c = min_l[level]
      min_l[level] = min(c, d)
    if e:
      queue.append((e, b))
    if node.right:
      queue.append((f, b))

  return min_l

#DRIVER CODE
root = tree_construction([None, 4,9,2,3,-5,None,7])
print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  3 9 5 4 2 7
print()
print('Level Wise Smallest Value: ', end = ' ')
print(smallest_level(root)) #Level Wise Smallest Value:  {0: 4, 1: 2, 2: -5}
# Out:
# Given Tree Inorder Traversal:  3 9 -5 4 2 7
# Level Wise Smallest Value:  {0: 4, 1: 2, 2: -5}

# %% [markdown]
# Task 3

# %%
def inorder_predecessor(root, x):

  #To Do
  if root == None or x == None:
    return None

  p = None
  c = root

  while c:
    if c.elem < x.elem:
      p = c
      c = c.right
    else:
      c = c.left

  return p

#DRIVER CODE
root = BTNode(20)
n1 = BTNode(8)
n2 = BTNode(22)
n3 = BTNode(4)
n4 = BTNode(12)
n5 = BTNode(10)
n6 = BTNode(14)

root.left = n1
root.right = n2

n1.left = n3
n1.right = n4

n4.left = n5
n4.right = n6

print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  4 8 10 12 14 20 22
print()

x = root
print(f'Inorder predecessor of node {x.elem}: {inorder_predecessor(root, x).elem}') #Inorder predecessor of node 20: 14
# Out:
# Given Tree Inorder Traversal:  4 8 10 12 14 20 22
# Inorder predecessor of node 20: 14

# %% [markdown]
# Task 4

# %%
def LCA(root, x, y):
  #To Do
  if root is None:
      return None
  a = root.elem
  b = root.left
  c = root.right
  if a > x and a > y:
      return LCA(b, x, y)
  elif a < x and a < y:
      return LCA(c, x, y)
  else:
      return root

#DRIVER CODE
#Write by yourself from the given tree
#check all the sample inputs given
root = BTNode(20)
n1 = BTNode(8)
n2 = BTNode(22)
n3 = BTNode(4)
n4 = BTNode(12)
n5 = BTNode(10)
n6 = BTNode(14)

root.left = n1
root.right = n2

n1.left = n3
n1.right = n4

n4.left = n5
n4.right = n6

# Sample Inputs
print(f'LCA(6, 12): {LCA(root, 6, 12).elem}')  # LCA(6, 12): 10
print(f'LCA(20, 6): {LCA(root, 20, 6).elem}')  # LCA(20, 6): 15
print(f'LCA(18, 22): {LCA(root, 18, 22).elem}')  # LCA(18, 22): 20
print(f'LCA(20, 25): {LCA(root, 20, 25).elem}')  # LCA(20, 25): 25
print(f'LCA(10, 12): {LCA(root, 10, 12).elem}')  # LCA(10, 12): 10
# Out:
# LCA(6, 12): 8
# LCA(20, 6): 20
# LCA(18, 22): 20
# LCA(20, 25): 20
# LCA(10, 12): 12

# %% [markdown]
# Task 5

# %%
def sumTree(root):

  # To DO
  if root is None:
    return 0

  a = root.elem
  b = root.left
  c = root.right
  return a + sumTree(b) + sumTree(c)

class BTNode:
  def __init__(self, elem):
    self.elem = elem
    self.left = None
    self.right = None
  #you can declare as many helper function with extra parameters as you need .
  #You can not modify the parameters of sumTree or modify any part of the given code.

# %%
#Driver Code
#Input 1
root1 = BTNode(9)
node2 = BTNode(4)
node3 = BTNode(5)
node4 = BTNode(18)
node5 = BTNode(14)
node6 = BTNode(3)
node7 = BTNode(54)
node8 = BTNode(12)
node9 = BTNode(8)
node10 = BTNode(91)
node11 = BTNode(56)

root1.left = node2
root1.right = node3

node2.left = node4

node3.left = node5
node3.right = node6

node4.left = node7
node4.right = node8

node5.left = node9

node8.left = node10
node8.right = node11

print(sumTree(root1)) #This should print 15
# Out:
# 274

# %% [markdown]
# Task 6

# %%
def swap_child(root, level, M):
  #To Do
  if root is None:
        return None
  a = root.left
  b = root.right
  c = level + 1
  if level == 0:
      tmp = a
      a = b
      b = tmp

  if level < M:
      swap_child(a, c, M)
      swap_child(b, c, M)

  return root

#Driver Code
root = BTNode('A')
#Write other nodes by yourself from the given tree of Doc File
def inorder(root):
  if root:
    inorder(root.left)
    print(root.elem, end=' ')
    inorder(root.right)

class BTNode:
  def __init__(self, elem):
    self.elem = elem
    self.left = None
    self.right = None

root = BTNode('A')
root.left = BTNode('B')
root.right = BTNode('C')
root.left.left = BTNode('D')
root.left.right = BTNode('E')
root.right.left = BTNode('F')
root.right.right = BTNode('G')
root.left.left.left = BTNode('H')
root.left.right.right = BTNode('I')
root.right.right.left = BTNode('J')


print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root)   #Given Tree Inorder Traversal: G D H B I E A C J F
print()

root2 = swap_child(root, 0, 2)
print('Swapped Tree Inorder Traversal: ', end = ' ')
inorder(root2)  #Swapped Tree Inorder Traversal: J F C A I E B G D H
# Out:
# Given Tree Inorder Traversal:  H D B E I A F C J G
# Swapped Tree Inorder Traversal:  H D B E I A F C J G

# %% [markdown]
# Task 7

# %%
def subtract_summation(root):
  #To Do
  if root == None:
        return 0

  x = root.elem
  return x - sumTree(root.elem) - sumTree(root.right)

class BTNode:
  def __init__(self, elem):
    self.elem = elem
    self.left = None
    self.right = None

#Driver Code
root=BTNode(71)
#Write other nodes by yourself from the given tree of Doc File
root.left = BTNode(23)
root.right = BTNode(17)
root.left.left = BTNode(9)
root.left.right = BTNode(14)
root.right.left = BTNode(6)
root.right.right = BTNode(11)
root.left.left.left = BTNode(3)
root.left.right.right = BTNode(5)
root.right.right.left = BTNode(7)


print(subtract_summation(root)) #This should print 111
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-8bdf595398b9> in <cell line: 29>()
#      27
#      28
# ---> 29 print(subtract_summation(root)) #This should print 111
#
# <ipython-input-57-8bdf595398b9> in subtract_summation(root)
#       5
#       6   x = root.elem
# ----> 7   return x - sumTree(root.elem) - sumTree(root.right)
#       8
#       9 class BTNode:
#
# <ipython-input-51-7437a359d7cd> in sumTree(root)
#       5     return 0
#       6
# ----> 7   a = root.elem
#       8   b = root.left
#       9   c = root.right
#
# AttributeError: 'int' object has no attribute 'elem'

# %% [markdown]
# Bonus Task

# %%
def level_sum(root):
  #To Do

#DRIVER CODE
root = BTNode(1)
n2 = BTNode(2)
n3 = BTNode(3)
n4 = BTNode(4)
n5 = BTNode(5)
n6 = BTNode(6)
n7 = BTNode(7)
n8 = BTNode(8)
root.left = n2
root.right = n3

n2.left = n4
n3.left = n5
n3.right = n6

n5.left = n7
n5.right = n8


print(level_sum(root)) #This should print 4
