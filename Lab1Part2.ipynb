# %%
import numpy as np


def mean(arr):
  sum = 0
  for i in range(1,len(arr)-1):
    sum = (sum+i)/len(arr)
  return sum

def standard_derivation(arr):
  for i in range(len(arr)):
    arr[i]=(arr[i]-mean)**2
    y = sum/len(arr)-1
    sd = sq.root(y)
  return sd


arr = [10, 8, 13, 9, 14, 25, -5, 20, 7, 7, 4]
mean(arr)
standard_derivation(arr)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-7626663c6857> in <cell line: 20>()
#      18 arr = [10, 8, 13, 9, 14, 25, -5, 20, 7, 7, 4]
#      19 mean(arr)
# ---> 20 standard_derivation(arr)
#
# <ipython-input-9-7626663c6857> in standard_derivation(arr)
#      10 def standard_derivation(arr):
#      11   for i in range(len(arr)):
# ---> 12     arr[i]=(arr[i]-mean)**2
#      13     y = sum/len(arr)-1
#      14     sd = sq.root(y)
#
# TypeError: unsupported operand type(s) for -: 'int' and 'function'
